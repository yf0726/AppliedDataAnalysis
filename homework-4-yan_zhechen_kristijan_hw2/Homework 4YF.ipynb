# %% [markdown]
# ## Assignment 4: Obsevational Studies and Applied ML
#
# ### Deadline
# November 21st,11:59PM
#
# ### Important notes
#
# Make sure you push on GitHub your notebook with all the cells already evaluated. Don't forget to add a textual description of your thought process, the assumptions you made, and the solution you implemented. Back up any hypotheses and claims with data, since this is an important aspect of the course. Please write all your comments in English, and use meaningful variable names in your code. Your repo should have a single notebook (plus the data files necessary) in the master branch. If there are multiple notebooks present, we will not grade anything.
#
# Use this legendary link to create your repository: [link](https://classroom.github.com/g/YXtsr0QK)

# %%
# Put your imports here
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
data_folder = './data/'

# %% [markdown]
# ## Task 1: Boosting the economy by incentivizing self-employment
#
# Assume the biggest priority of the local government in 2018 is to increase per-capita income. To do so, the officials plan to adopt a strategy for incentivizing self-employment through a series of campaigns, educational programs, and dedicated funds.
#
# Since it is unethical and impossible in this setting to run a controlled experiment involving citizens (e.g., fire employees and force them to self-employ), the officials have asked you, the data scientist, to establish the effect of self-employment on the economy, relying on observational data.
#
# **A)** You will be working with the full US 2015 census dataset (acs2015_county_data.csv, available at https://www.kaggle.com/muonneutrino/us-census-demographic-data#acs2015_county_data.csv). Using suitable methods, determine and quantify the dependency between the percentage of self-employed citizens and per capita income across all 3,212 US counties. Do citizens in counties that have a higher percentage of self-employed people earn more per capita?
#
# **B)** The pilot program will involve all counties within a limited set of three US states. Set A includes Wisconsin, Tennessee, and  Minnesota. Quantify the dependency of per-capita income on self-employment rates across all the counties in set A.
#
# **C)** In which state within set A is the observed effect of self-employment on per-capita income the strongest?
#
# **D)** Set B includes New Jersey, Kansas, and Rhode Island. Repeat the analysis from steps B and C above, but now for set B. In which of the two sets A and B (if any) would you recommend incentivizing self-employment? Explain your reasoning.
#
# Hint: It is useful to add a notion of confidence to your results and explore the data visually. You are allowed to use the SciPy library.

# %% [markdown]
# ### Task 1 A

# %%
census = pd.read_csv(data_folder+'acs2015_county_data.csv')

# %%
census[['State','County','TotalPop','IncomePerCap','IncomePerCapErr','SelfEmployed']]
# Out:
#             State         County  TotalPop  IncomePerCap  IncomePerCapErr  \
# 0         Alabama        Autauga     55221         24974             1080
# 1         Alabama        Baldwin    195121         27317              711
# 2         Alabama        Barbour     26932         16824              798
# 3         Alabama           Bibb     22604         18431             1618
# 4         Alabama         Blount     57710         20532              708
# 5         Alabama        Bullock     10678         17580             2055
# 6         Alabama         Butler     20354         18390              714
# 7         Alabama        Calhoun    116648         21374              489
# 8         Alabama       Chambers     34079         21071             1366
# 9         Alabama       Cherokee     26008         21811             1556
# 10        Alabama        Chilton     43819         21399             1446
# 11        Alabama        Choctaw     13395         20755             1380
# 12        Alabama         Clarke     25070         20064             1469
# 13        Alabama           Clay     13537         18905             1067
# 14        Alabama       Cleburne     15002         20151             1357
# 15        Alabama         Coffee     50884         24936              854
# 16        Alabama        Colbert     54444         22546              917
# 17        Alabama        Conecuh     12865         15968             1369
# 18        Alabama          Coosa     11027         17519              961
# 19        Alabama      Covington     37886         20977              723
# 20        Alabama       Crenshaw     13938         20585             1229
# 21        Alabama        Cullman     80965         20881              727
# 22        Alabama           Dale     49866         22566              911
# 23        Alabama         Dallas     42154         17808              788
# 24        Alabama         DeKalb     71068         18411              588
# 25        Alabama         Elmore     80763         24381              941
# 26        Alabama       Escambia     37935         17045              848
# 27        Alabama         Etowah    103766         20500              518
# 28        Alabama        Fayette     16896         19545             1183
# 29        Alabama       Franklin     31634         18595              975
# ...           ...            ...       ...           ...              ...
# 3190  Puerto Rico        Maunabo     11701          8374             1191
# 3191  Puerto Rico       Mayagüez     83418          9930              644
# 3192  Puerto Rico           Moca     38815          7685              512
# 3193  Puerto Rico        Morovis     32294          7465              487
# 3194  Puerto Rico        Naguabo     26804          9749             1675
# 3195  Puerto Rico      Naranjito     29751          9347             1337
# 3196  Puerto Rico       Orocovis     22595          6792              462
# 3197  Puerto Rico       Patillas     18441          7643              891
# 3198  Puerto Rico       Peñuelas     22770          7299              413
# 3199  Puerto Rico          Ponce    156054         10562              389
# 3200  Puerto Rico   Quebradillas     25205          8649             1022
# 3201  Puerto Rico         Rincón     14841          9412              795
# 3202  Puerto Rico     Río Grande     53029         10363              457
# 3203  Puerto Rico  Sabana Grande     24307          7943              551
# 3204  Puerto Rico        Salinas     30114          8286              424
# 3205  Puerto Rico     San Germán     34125          9399              663
# 3206  Puerto Rico       San Juan    371400         16691              437
# 3207  Puerto Rico    San Lorenzo     39778         10021             1054
# 3208  Puerto Rico  San Sebastián     40471          7519              467
# 3209  Puerto Rico   Santa Isabel     22913          9199              749
# 3210  Puerto Rico       Toa Alta     74603         13689              541
# 3211  Puerto Rico       Toa Baja     85242         11673              396
# 3212  Puerto Rico  Trujillo Alto     71886         15409              793
# 3213  Puerto Rico         Utuado     31474          7717              331
# 3214  Puerto Rico      Vega Alta     39319          9918             1103
# 3215  Puerto Rico      Vega Baja     56858          9102              538
# 3216  Puerto Rico        Vieques      9130          8821              939
# 3217  Puerto Rico       Villalba     24685          8420              486
# 3218  Puerto Rico        Yabucoa     36279          7960              512
# 3219  Puerto Rico          Yauco     39474          7743              474
#
#       SelfEmployed
# 0              5.5
# 1              5.8
# 2              7.3
# 3              6.7
# 4              4.2
# 5              5.4
# 6              6.2
# 7              5.0
# 8              2.8
# 9              7.9
# 10             4.1
# 11             5.4
# 12             3.3
# 13             7.8
# 14             8.4
# 15             5.7
# 16             5.2
# 17             8.3
# 18             5.9
# 19             6.7
# 20             7.9
# 21             5.8
# 22             5.9
# 23             6.2
# 24             8.5
# 25             5.5
# 26             6.4
# 27             5.6
# 28             3.8
# 29             6.9
# ...            ...
# 3190           4.8
# 3191           8.5
# 3192          11.7
# 3193           4.4
# 3194          14.0
# 3195           6.5
# 3196           8.9
# 3197           4.2
# 3198           8.2
# 3199           9.5
# 3200           9.3
# 3201           9.1
# 3202           6.4
# 3203           3.0
# 3204           6.0
# 3205           9.8
# 3206          13.4
# 3207           6.2
# 3208          10.9
# 3209           6.0
# 3210           7.8
# 3211           7.7
# 3212          10.1
# 3213           7.3
# 3214           4.1
# 3215           4.1
# 3216          13.6
# 3217          13.1
# 3218           7.3
# 3219           4.4
#
# [3220 rows x 6 columns]

# %%
census['IncomePerCap'].corr(census['SelfEmployed'],method = 'pearson')
# Out:
# 0.08727386609551799

# %% [markdown]
# ### Task 1B & C

# %%
setA = census.query('State==["Wisconsin","Tennessee", "Minnesota"]')[['State','IncomePerCap','SelfEmployed']]

# %%
setA['IncomePerCap'].corr(setA['SelfEmployed'],method = 'pearson')
# Out:
# -0.2022935073652149

# %%
fig, axs = plt.subplots(1, 3, sharey=True)
setA.loc[setA['State']=="Wisconsin"].plot(kind='scatter', x='SelfEmployed', y='IncomePerCap', ax=axs[0], figsize=(16, 8), grid=True)
setA.loc[setA['State']=="Tennessee"].plot(kind='scatter', x='SelfEmployed', y='IncomePerCap', ax=axs[1], grid=True)
setA.loc[setA['State']=="Minnesota"].plot(kind='scatter', x='SelfEmployed', y='IncomePerCap', ax=axs[2], grid=True)

# %%
Wiscon = setA.loc[setA['State']=="Wisconsin"]
Wiscon['IncomePerCap'].corr(Wiscon['SelfEmployed'],method = 'pearson')
# Out:
# -0.32905300016378525

# %%
Tenne = setA.loc[setA['State']=="Tennessee"]
Tenne['IncomePerCap'].corr(Tenne['SelfEmployed'],method = 'pearson')
# Out:
# -0.23836048684913158

# %%
Minne = setA.loc[setA['State']=="Minnesota"]
Minne['IncomePerCap'].corr(Minne['SelfEmployed'],method = 'pearson')
# Out:
# -0.2538551921654063

# %% [markdown]
# ### Task 1 D

# %%
setB = census.query('State==["New Jersey", "Kansas", "Rhode Island"]')[['State','IncomePerCap','SelfEmployed']]

# %%
setB['IncomePerCap'].corr(setB['SelfEmployed'],method = 'pearson')
# Out:
# -0.2322214134608568

# %%
fig, axs = plt.subplots(1, 3, sharey=True)
setB.loc[setB['State']=="New Jersey"].plot(kind='scatter', x='SelfEmployed', y='IncomePerCap', ax=axs[0], figsize=(16, 8), grid=True)
setB.loc[setB['State']=="Kansas"].plot(kind='scatter', x='SelfEmployed', y='IncomePerCap', ax=axs[1], grid=True)
setB.loc[setB['State']=="Rhode Island"].plot(kind='scatter', x='SelfEmployed', y='IncomePerCap', ax=axs[2], grid=True)

# %% [markdown]
# ## Task 2: All you need is love… And a dog!
#
# Here we are going to build a classifier to predict whether an animal from an animal shelter will be adopted or not (aac_intakes_outcomes.csv, available at: https://www.kaggle.com/aaronschlegel/austin-animal-center-shelter-intakes-and-outcomes/version/1#aac_intakes_outcomes.csv). You will be working with the following features:
#
# 1. *animal_type:* Type of animal. May be one of 'cat', 'dog', 'bird', etc.
# 2. *intake_year:* Year of intake
# 3. *intake_condition:* The intake condition of the animal. Can be one of 'normal', 'injured', 'sick', etc.
# 4. *intake_number:* The intake number denoting the number of occurrences the animal has been brought into the shelter. Values higher than 1 indicate the animal has been taken into the shelter on more than one occasion.
# 5. *intake_type:* The type of intake, for example, 'stray', 'owner surrender', etc.
# 6. *sex_upon_intake:* The gender of the animal and if it has been spayed or neutered at the time of intake
# 7. *age_upon\_intake_(years):* The age of the animal upon intake represented in years
# 8. *time_in_shelter_days:* Numeric value denoting the number of days the animal remained at the shelter from intake to outcome.
# 9. *sex_upon_outcome:* The gender of the animal and if it has been spayed or neutered at time of outcome
# 10. *age_upon\_outcome_(years):* The age of the animal upon outcome represented in years
# 11. *outcome_type:* The outcome type. Can be one of ‘adopted’, ‘transferred’, etc.
#
# **A)** Load the dataset and convert categorical features to a suitable numerical representation (use dummy-variable encoding). Split the data into a training set (80%) and a test set (20%). Pair each feature vector with the corresponding label, i.e., whether the outcome_type is adoption or not. Standardize the values of each feature in the data to have mean 0 and variance 1. The use of external libraries is not permitted in part A, except for numpy and pandas.
#
# **B)** Train a logistic regression classifier on your training set. Logistic regression returns probabilities as predictions, so in order to arrive at a binary prediction, you need to put a threshold on the predicted probabilities. For the decision threshold of 0.5, present the performance of your classifier on the test set by displaying the confusion matrix. Based on the confusion matrix, manually calculate accuracy, precision, recall, and F1-score with respect to the positive and the negative class. Vary the value of the threshold in the range from 0 to 1 and visualize the value of accuracy, precision, recall, and F1-score (with respect to both classes) as a function of the threshold. The shelter has a limited capacity and has no other option but to put to sleep animals with a low probability of adoption. What metric (precision, recall, accuracy, or F1-score) and with respect to what class is the most relevant when choosing the threshold in this scenario, and why? Explain your reasoning.
#
# **C)** Reduce the number of features by selecting the subset of the k best features. Use greedy backward selection to iteratively remove features. Evaluate performance and visualize the result using 5-fold cross-validation on the training set as a function of k, where k = 1, 5, 10, 15, 20, 25, 30. Choose the optimal k and justify your choice. Interpret the top-k features and their impact on the probability of adoption.
#
# **D)** Train a random forest. Use 5-fold cross-validation on the training set to fine-tune the parameters of the classifier using a grid search on the number of estimators "n_estimators" and the max depth of the trees "max_depth". For the chosen parameters, estimate the performance of your classifier on the test set by presenting the confusion matrix, accuracy, precision, recall, and F1-score with respect to both classes and compare the performance with the performance of the logistic regression. Interpret the results.
#
# You are allowed to use the scikit-learn library to implement your classifiers.

# %% [markdown]
# ### Task 2 A

# %%
intake = pd.read_csv(data_folder+'aac_intakes_outcomes.csv')
intake = intake.dropna()

# %%
features = intake[['animal_type','intake_year','intake_condition','intake_number','intake_type',
                   'sex_upon_intake','age_upon_intake_(years)','time_in_shelter_days','sex_upon_outcome',
                  'age_upon_outcome_(years)']]

# %%
features
# Out:
#       animal_type  intake_year intake_condition  intake_number  \
# 3             Dog         2014           Normal            1.0
# 11            Cat         2014           Normal            1.0
# 12            Dog         2013           Normal            1.0
# 13            Dog         2015             Sick            1.0
# 14            Dog         2016             Aged            1.0
# 16            Cat         2013             Aged            1.0
# 18            Dog         2013             Sick            1.0
# 19            Dog         2013             Sick            1.0
# 20            Dog         2015          Injured            1.0
# 22            Dog         2015           Normal            1.0
# 24            Dog         2015             Aged            1.0
# 28            Dog         2016           Normal            1.0
# 30            Dog         2015           Normal            1.0
# 32            Dog         2016           Normal            1.0
# 33            Dog         2016             Aged            1.0
# 38            Dog         2014           Normal            1.0
# 40            Cat         2014             Sick            1.0
# 41            Cat         2014           Normal            1.0
# 44            Cat         2014           Normal            1.0
# 46            Dog         2015           Normal            1.0
# 47            Dog         2014           Normal            1.0
# 49            Cat         2016             Sick            1.0
# 52            Dog         2014           Normal            1.0
# 53            Dog         2013           Normal            1.0
# 56            Dog         2015             Sick            1.0
# 62            Cat         2014           Normal            1.0
# 65            Cat         2017          Injured            1.0
# 73            Dog         2015             Sick            1.0
# 74            Cat         2016             Aged            1.0
# 75            Dog         2014           Normal            1.0
# ...           ...          ...              ...            ...
# 79607       Other         2018           Normal            1.0
# 79610         Dog         2018           Normal            1.0
# 79611         Dog         2018           Normal            1.0
# 79612         Cat         2018           Normal            1.0
# 79614         Cat         2018           Normal            1.0
# 79615         Cat         2018           Normal            1.0
# 79616       Other         2018           Normal            1.0
# 79620       Other         2018           Normal            1.0
# 79622         Cat         2018           Normal            1.0
# 79623       Other         2018           Normal            1.0
# 79624         Dog         2018           Normal            1.0
# 79629         Cat         2018           Normal            1.0
# 79631         Dog         2018           Normal            1.0
# 79639         Cat         2018           Normal            1.0
# 79644         Dog         2018           Normal            1.0
# 79648       Other         2018           Normal            1.0
# 79650         Cat         2018           Normal            1.0
# 79651       Other         2018           Normal            1.0
# 79652         Dog         2018           Normal            1.0
# 79656         Dog         2018           Normal            1.0
# 79661         Cat         2018           Normal            1.0
# 79662         Cat         2018           Normal            1.0
# 79663         Cat         2018           Normal            1.0
# 79664         Cat         2018           Normal            1.0
# 79665         Cat         2018           Normal            1.0
# 79666         Cat         2018           Normal            1.0
# 79667         Cat         2018           Normal            1.0
# 79668       Other         2018           Normal            1.0
# 79669       Other         2018           Normal            1.0
# 79671         Dog         2018             Aged            1.0
#
#               intake_type sex_upon_intake  age_upon_intake_(years)  \
# 3         Owner Surrender   Neutered Male                10.000000
# 11                  Stray   Spayed Female                14.000000
# 12        Owner Surrender   Neutered Male                16.000000
# 13        Owner Surrender   Neutered Male                14.000000
# 14          Public Assist   Neutered Male                17.000000
# 16     Euthanasia Request   Spayed Female                19.000000
# 18        Owner Surrender   Neutered Male                15.000000
# 19        Owner Surrender   Neutered Male                15.000000
# 20                  Stray   Spayed Female                16.000000
# 22                  Stray   Neutered Male                15.000000
# 24     Euthanasia Request     Intact Male                13.000000
# 28                  Stray   Neutered Male                15.000000
# 30                  Stray   Neutered Male                15.000000
# 32                  Stray   Spayed Female                15.000000
# 33     Euthanasia Request   Spayed Female                14.000000
# 38                  Stray   Spayed Female                17.000000
# 40     Euthanasia Request   Spayed Female                14.000000
# 41                  Stray   Neutered Male                14.000000
# 44     Euthanasia Request   Neutered Male                20.000000
# 46     Euthanasia Request   Spayed Female                13.000000
# 47                  Stray   Neutered Male                12.000000
# 49        Owner Surrender   Spayed Female                14.000000
# 52                  Stray   Neutered Male                12.000000
# 53        Owner Surrender   Neutered Male                12.000000
# 56        Owner Surrender   Spayed Female                13.000000
# 62        Owner Surrender   Spayed Female                11.000000
# 65                  Stray   Spayed Female                15.000000
# 73     Euthanasia Request   Spayed Female                13.000000
# 74                  Stray   Spayed Female                13.000000
# 75        Owner Surrender   Spayed Female                10.000000
# ...                   ...             ...                      ...
# 79607            Wildlife         Unknown                 1.000000
# 79610               Stray     Intact Male                 5.000000
# 79611               Stray     Intact Male                 1.000000
# 79612               Stray     Intact Male                 2.000000
# 79614               Stray     Intact Male                 0.008219
# 79615               Stray     Intact Male                 0.008219
# 79616            Wildlife         Unknown                 1.000000
# 79620            Wildlife         Unknown                 1.000000
# 79622               Stray   Intact Female                 0.410959
# 79623            Wildlife         Unknown                 1.000000
# 79624               Stray   Intact Female                 2.000000
# 79629               Stray     Intact Male                 2.000000
# 79631               Stray     Intact Male                 0.082192
# 79639     Owner Surrender     Intact Male                 0.082192
# 79644               Stray   Intact Female                 0.095890
# 79648               Stray         Unknown                 1.000000
# 79650               Stray     Intact Male                 1.000000
# 79651               Stray         Unknown                 1.000000
# 79652               Stray   Intact Female                 0.082192
# 79656               Stray   Intact Female                 0.164384
# 79661               Stray     Intact Male                 3.000000
# 79662               Stray         Unknown                 0.038356
# 79663               Stray         Unknown                 0.038356
# 79664               Stray         Unknown                 0.038356
# 79665               Stray         Unknown                 0.038356
# 79666               Stray         Unknown                 0.038356
# 79667               Stray         Unknown                 0.038356
# 79668            Wildlife         Unknown                 2.000000
# 79669            Wildlife         Unknown                 1.000000
# 79671               Stray   Spayed Female                10.000000
#
#        time_in_shelter_days sex_upon_outcome  age_upon_outcome_(years)
# 3                  4.970139    Neutered Male                 10.000000
# 11                14.120139    Spayed Female                 14.000000
# 12                49.747917    Neutered Male                 16.000000
# 13                 0.130556    Neutered Male                 14.000000
# 14                 9.020139    Neutered Male                 17.000000
# 16                 0.067361    Spayed Female                 19.000000
# 18                 0.066667    Neutered Male                 15.000000
# 19                 0.068056    Neutered Male                 15.000000
# 20                 0.940278    Spayed Female                 16.000000
# 22                23.104861    Neutered Male                 15.000000
# 24                 0.070139      Intact Male                 13.000000
# 28                 7.843750    Neutered Male                 15.000000
# 30                 4.552083    Neutered Male                 15.000000
# 32                89.855556    Spayed Female                 15.000000
# 33                 0.056250    Spayed Female                 14.000000
# 38                 4.018056    Spayed Female                 17.000000
# 40                 0.088194    Spayed Female                 14.000000
# 41                 3.814583    Neutered Male                 14.000000
# 44                 0.090972    Neutered Male                 20.000000
# 46                 0.045139    Spayed Female                 13.000000
# 47                 6.709028    Neutered Male                 12.000000
# 49                 5.841667    Spayed Female                 14.000000
# 52                 9.055556    Neutered Male                 12.000000
# 53               146.964583    Neutered Male                 12.000000
# 56                 0.299306    Spayed Female                 13.000000
# 62                10.938194    Spayed Female                 11.000000
# 65                 5.815278    Spayed Female                 15.000000
# 73                 0.052083    Spayed Female                 13.000000
# 74                51.179167    Spayed Female                 13.000000
# 75               147.842361    Spayed Female                 11.000000
# ...                     ...              ...                       ...
# 79607              0.077083          Unknown                  1.000000
# 79610              5.940278    Neutered Male                  5.000000
# 79611              4.191667    Neutered Male                  1.000000
# 79612              4.113194      Intact Male                  2.000000
# 79614              0.001389      Intact Male                  0.008219
# 79615              0.001389      Intact Male                  0.008219
# 79616              0.027083          Unknown                  1.000000
# 79620              0.011111          Unknown                  1.000000
# 79622              0.887500    Intact Female                  0.410959
# 79623              0.858333          Unknown                  1.000000
# 79624              6.046528    Spayed Female                  2.000000
# 79629              3.190972      Intact Male                  2.000000
# 79631              4.995833    Neutered Male                  0.082192
# 79639              4.981944      Intact Male                  0.164384
# 79644              0.646528    Intact Female                  0.082192
# 79648              1.820139          Unknown                  1.000000
# 79650              3.047917      Intact Male                  1.000000
# 79651              0.020139          Unknown                  1.000000
# 79652              0.884028    Intact Female                  0.082192
# 79656              4.075000    Intact Female                  0.164384
# 79661              4.168750      Intact Male                  3.000000
# 79662              0.075694          Unknown                  0.038356
# 79663              0.076389          Unknown                  0.038356
# 79664              0.076389          Unknown                  0.038356
# 79665              0.076389          Unknown                  0.038356
# 79666              0.708333          Unknown                  0.038356
# 79667              0.077083          Unknown                  0.038356
# 79668              0.053472          Unknown                  2.000000
# 79669              0.047917          Unknown                  1.000000
# 79671              0.813889    Spayed Female                 10.000000
#
# [36348 rows x 10 columns]

# %%
x = pd.get_dummies(features)
y = pd.get_dummies(intake['outcome_type']).Adoption

# %%
x.columns
# Out:
# Index(['intake_year', 'intake_number', 'age_upon_intake_(years)',
#        'time_in_shelter_days', 'age_upon_outcome_(years)', 'animal_type_Bird',
#        'animal_type_Cat', 'animal_type_Dog', 'animal_type_Other',
#        'intake_condition_Aged', 'intake_condition_Feral',
#        'intake_condition_Injured', 'intake_condition_Normal',
#        'intake_condition_Nursing', 'intake_condition_Other',
#        'intake_condition_Pregnant', 'intake_condition_Sick',
#        'intake_type_Euthanasia Request', 'intake_type_Owner Surrender',
#        'intake_type_Public Assist', 'intake_type_Stray',
#        'intake_type_Wildlife', 'sex_upon_intake_Intact Female',
#        'sex_upon_intake_Intact Male', 'sex_upon_intake_Neutered Male',
#        'sex_upon_intake_Spayed Female', 'sex_upon_intake_Unknown',
#        'sex_upon_outcome_Intact Female', 'sex_upon_outcome_Intact Male',
#        'sex_upon_outcome_Neutered Male', 'sex_upon_outcome_Spayed Female',
#        'sex_upon_outcome_Unknown'],
#       dtype='object')

# %%
x_standardize = x.apply(lambda x: (x-np.mean(x))/np.std(x))

# %%
# split the dataset into 20% and 80%
# same random seed ensuring that there is not overlapping in test set and training set
# and x,y has same index in test set and training set
x_test = x_standardize.sample(frac=0.2,random_state=10)
x_train = x_standardize.sample(frac=0.8,random_state=10)
y_test = y.sample(frac=0.2,random_state=10)
y_train = y.sample(frac=0.8,random_state=10)

# %% [markdown]
# **B)** Train a logistic regression classifier on your training set. Logistic regression returns probabilities as predictions, so in order to arrive at a binary prediction, you need to put a threshold on the predicted probabilities. For the decision threshold of 0.5, present the performance of your classifier on the test set by displaying the confusion matrix. Based on the confusion matrix, manually calculate accuracy, precision, recall, and F1-score with respect to the positive and the negative class. Vary the value of the threshold in the range from 0 to 1 and visualize the value of accuracy, precision, recall, and F1-score (with respect to both classes) as a function of the threshold. The shelter has a limited capacity and has no other option but to put to sleep animals with a low probability of adoption. What metric (precision, recall, accuracy, or F1-score) and with respect to what class is the most relevant when choosing the threshold in this scenario, and why? Explain your reasoning.

# %%
logistic = LogisticRegression(solver='liblinear')
logistic.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred_prob = logistic.predict_proba(x_test)
threshold_list = np.linspace(0,1,num=21)
for thresh in threshold_list:
    print ('\n******** For i = {} ******'.format(thresh))
    y_pred_tmp = (y_pred_prob[:,1] > = thresh).astype(int)
#    test_accuracy = 
#     print('Our testing accuracy is {}'.format(test_accuracy))

#     print(confusion_matrix(Y_test.as_matrix().reshape(Y_test.as_matrix().size,1),
#                            Y_test_pred.iloc[:,1].as_matrix().reshape(Y_test_pred.iloc[:,1].as_matrix().size,1)))

# %%
y_pred_prob = logistic.predict_proba(x_test)
y_pred_tmp =(y_pred_prob[:,1] >= 0.5).astype(int)
df_confusion = pd.crosstab(pd.Series(y_test.get_values(), name='Actual'), pd.Series(y_pred_tmp, name='Predicted'), margins=True)
df_confusion

# %%
def compute_confusion_matrix(true, predicted):
    '''
    Computes a confusion matrix using numpy for two np.arrays true and pred.
    
    Parameters:
        true: numpy array
        predicted: numpy array
        
    Return:
        confusion matrix with K number of classes
    '''
    
    K = len(np.unique(true)) # Number of classes 
    result = np.zeros((K, K))
    
    for i in range(len(true)):
        result[true[i]][predicted[i]] += 1
        
    return result

# %%
def calculate_accuracy(confusion_matrix):
    """
    Calculates model accuracy: Overall, how often is the classifier correct? 
    Same for positive and negative class.
    The formula: (TruePositives + TrueNegatives) / total

    Parameters:
        confusion_matrix: numpy array
        
    Return:
        model accuracy
    """
    return np.sum(np.diag(confusion_matrix))/np.sum(confusion_matrix)

# %%
def calculate_precision(confusion_matrix, precision_class):
    """
    Calculates model precision: When it predicts yes, how often is it correct? 
                                And vice versa, when it predicts no, how often is it correct?
    
    The formulas: TruePositives / (TruePositives + FalsePositives) or TP/predicted yes
                  TrueNegatives / (TrueNegatives + FalseNegatives) or TN/predicted no

    Parameters:
        confusion_matrix: numpy array
        precision_class: 0 for negative class or 1 for positive class
        
    Return:
        precision for desired class
    """
    # Precision for positive class
    if precision_class == 1:
        return confusion_matrix[1,1]/np.sum(confusion_matrix[:,1])
    
    # Precision for negative class
    elif precision_class == 0:
        if np.sum(confusion_matrix[:,0]) == 0:
            return 0
        else:
            return confusion_matrix[0,0]/np.sum(confusion_matrix[:,0])
    
    else:
        print('Input correct value for the precision class. (0 for negative and 1 for positive class)')

# %%
def calculate_recall(confusion_matrix, precision_class):
    """
    Calculates model recall: When it's actually yes, how often does it predict yes? 
                              And vice versa, when it's actually no, how often does it predict no?
                                
    The formulas: TruePositives / (TruePositives + FalseNegatives) or TP/actual yes
                  TrueNegatives / (TrueNegatives + FalsePositives) or TN/actual no

    Parameters:
        confusion_matrix: numpy array
        precision_class: 0 for negative class or 1 for positive class
        
    Return:
        recall for desired class
    """
    # Precision for positive class
    if precision_class == 1:
        return confusion_matrix[1,1]/np.sum(confusion_matrix[1,:])
    
    # Precision for negative class
    elif precision_class == 0:
        return confusion_matrix[0,0]/np.sum(confusion_matrix[0,:])
    
    else:
        print('Input correct value for the precision class. (0 for negative and 1 for positive class)')

# %%
def calculate_f1_score(confusion_matrix, precision_class):
    """
    Calculates model F1 score: Harmonic mean of precision and recall based on the confusion matrix and the precision class.
                       
    Parameters:
        confusion_matrix: numpy array
        precision_class: 0 for negative class or 1 for positive class
        
    Return:
        f1_score for desired class
    """
    # Precision for positive class
    if precision_class == 1:
        return 2 * calculate_precision(confusion_matrix,1) * calculate_recall(confusion_matrix,1)\
                / (calculate_precision(confusion_matrix,1) + calculate_recall(confusion_matrix,1))
    
    # Precision for negative class
    elif precision_class == 0:
        if np.sum(confusion_matrix[:,0]) == 0:
            return 0
        else:
            return 2 * calculate_precision(confusion_matrix,0) * calculate_recall(confusion_matrix,0)\
                / (calculate_precision(confusion_matrix,0) + calculate_recall(confusion_matrix,0))
    
    else:
        print('Input correct value for the precision class. (0 for negative and 1 for positive class)')

# %% [markdown]
# **C)** Reduce the number of features by selecting the subset of the k best features. Use greedy backward selection to iteratively remove features. Evaluate performance and visualize the result using 5-fold cross-validation on the training set as a function of k, where k = 1, 5, 10, 15, 20, 25, 30. Choose the optimal k and justify your choice. Interpret the top-k features and their impact on the probability of adoption.

# %%
logistic = LogisticRegression(solver='liblinear')
fitting = logistic.fit(x_train, y_train)

# %%
y_pred_prob = fitting.predict_proba(x_test)

# %%
names = x_test.columns
x_test.drop(columns = names[1])
# Out:
#        intake_year  age_upon_intake_(years)  time_in_shelter_days  \
# 76153     1.301194                -0.605988             -0.393074
# 47869     0.519845                -0.259290             -0.404688
# 33041    -0.261503                 3.051474             -0.319851
# 23904    -1.042851                -0.605988             -0.391675
# 56601     0.519845                -0.605988             -0.401642
# 19905    -1.042851                -0.259290             -0.345817
# 13789    -1.042851                -0.624129             -0.405387
# 53374     0.519845                -0.598933              0.400784
# 7560     -1.824199                 0.108573             -0.389402
# 31902    -0.261503                -0.620097              1.131080
# 48529     0.519845                -0.624129             -0.391267
# 55942     0.519845                -0.598933             -0.404644
# 65361     1.301194                 1.212161             -0.402225
# 72934     1.301194                -0.259290             -0.395872
# 4722     -1.824199                -0.475976             -0.347216
# 30075     1.301194                -0.259290             -0.331916
# 57727     0.519845                 3.051474              0.296712
# 47032     0.519845                -0.259290             -0.317315
# 60734     0.519845                -0.259290             -0.155145
# 50901     0.519845                -0.598933              2.239384
# 33940    -0.261503                -0.475976             -0.403988
# 79533     2.082542                -0.259290             -0.257031
# 15268    -1.042851                -0.591878              0.565213
# 57222     0.519845                -0.259290             -0.389052
# 56084     0.519845                -0.620097             -0.211145
# 23907    -1.042851                -0.605988             -0.391675
# 67638     1.301194                -0.566682             -0.303239
# 48110     0.519845                -0.596917              3.368437
# 71207     1.301194                -0.622113             -0.404003
# 64009     1.301194                -0.566682             -0.340703
# ...            ...                      ...                   ...
# 49657     0.519845                 3.419336             -0.153673
# 45147     0.519845                -0.445741              4.943491
# 72207     1.301194                -0.475976             -0.354939
# 33537    -0.261503                -0.259290             -0.389358
# 24133    -1.042851                -0.259290             -0.388498
# 66693     1.301194                 3.051474             -0.364921
# 38400    -0.261503                 0.108573             -0.280915
# 13865    -1.042851                -0.475976             -0.159080
# 47408     0.519845                -0.613043             -0.322255
# 15001    -1.042851                -0.591878              0.494539
# 54838     0.519845                -0.605988              1.483558
# 34836    -0.261503                 2.683611             -0.134614
# 50723     0.519845                 3.787199             -0.299421
# 15027    -1.042851                 0.108573             -0.009908
# 39254    -0.261503                -0.596917             -0.303268
# 42800    -0.261503                 1.580023              0.043498
# 64985     1.301194                 0.108573             -0.406597
# 27308    -0.261503                -0.259290             -0.388032
# 70328     1.301194                -0.259290             -0.321774
# 73876     1.301194                -0.259290             -0.302423
# 51568     0.519845                 1.212161              0.704927
# 58388     0.519845                 0.108573             -0.406640
# 42901    -0.261503                -0.259290             -0.406888
# 28275    -0.261503                 0.476435             -0.406582
# 13551    -1.042851                -0.620097             -0.405241
# 79106     2.082542                -0.415505             -0.321031
# 24336    -1.042851                -0.566682             -0.367806
# 796      -0.261503                 1.947886             -0.339741
# 1012     -1.824199                 2.315748             -0.282153
# 34370    -0.261503                -0.259290              0.449716
#
#        age_upon_outcome_(years)  animal_type_Bird  animal_type_Cat  \
# 76153                 -0.609969         -0.073820        -1.028297
# 47869                 -0.272089         -0.073820        -1.028297
# 33041                  3.021482         -0.073820        -1.028297
# 23904                 -0.616987         -0.073820         0.972481
# 56601                 -0.616987         -0.073820         0.972481
# 19905                 -0.272089         -0.073820         0.972481
# 13789                 -0.635034         -0.073820         0.972481
# 53374                 -0.577885         -0.073820         0.972481
# 7560                   0.093863         -0.073820        -1.028297
# 31902                 -0.577885         -0.073820         0.972481
# 48529                 -0.635034         -0.073820         0.972481
# 55942                 -0.609969         -0.073820         0.972481
# 65361                  1.191720         -0.073820         0.972481
# 72934                 -0.272089         -0.073820        -1.028297
# 4722                  -0.487650         -0.073820        -1.028297
# 30075                 -0.272089         -0.073820         0.972481
# 57727                  3.021482         -0.073820         0.972481
# 47032                 -0.272089         -0.073820         0.972481
# 60734                 -0.272089         -0.073820        -1.028297
# 50901                 -0.487650         -0.073820         0.972481
# 33940                 -0.487650         -0.073820        -1.028297
# 79533                 -0.272089         -0.073820         0.972481
# 15268                 -0.577885         -0.073820         0.972481
# 57222                 -0.272089         -0.073820         0.972481
# 56084                 -0.624005         -0.073820        -1.028297
# 23907                 -0.616987         -0.073820         0.972481
# 67638                 -0.547807         -0.073820        -1.028297
# 48110                 -0.427494         -0.073820         0.972481
# 71207                 -0.633029         -0.073820         0.972481
# 64009                 -0.577885         -0.073820         0.972481
# ...                         ...               ...              ...
# 49657                  3.387435         -0.073820        -1.028297
# 45147                 -0.272089         -0.073820         0.972481
# 72207                 -0.457572         -0.073820         0.972481
# 33537                 -0.272089         -0.073820         0.972481
# 24133                 -0.272089         -0.073820         0.972481
# 66693                  3.021482         -0.073820        -1.028297
# 38400                  0.093863         -0.073820        -1.028297
# 13865                 -0.457572         -0.073820         0.972481
# 47408                 -0.616987         -0.073820        -1.028297
# 15001                 -0.577885         -0.073820         0.972481
# 54838                 -0.547807         -0.073820         0.972481
# 34836                  3.021482         -0.073820        -1.028297
# 50723                  3.753387         -0.073820         0.972481
# 15027                  0.093863         -0.073820        -1.028297
# 39254                 -0.607963         -0.073820         0.972481
# 42800                  1.557673         -0.073820         0.972481
# 64985                  0.093863         -0.073820        -1.028297
# 27308                 -0.272089         -0.073820         0.972481
# 70328                 -0.272089         -0.073820         0.972481
# 73876                 -0.272089         -0.073820         0.972481
# 51568                  1.191720         -0.073820        -1.028297
# 58388                  0.093863         13.546498        -1.028297
# 42901                 -0.272089         -0.073820        -1.028297
# 28275                  0.459816         -0.073820        -1.028297
# 13551                 -0.631023         -0.073820         0.972481
# 79106                 -0.397415         -0.073820         0.972481
# 24336                 -0.577885         -0.073820         0.972481
# 796                    1.923625         -0.073820        -1.028297
# 1012                   2.289577         -0.073820        -1.028297
# 34370                 -0.272089         -0.073820        -1.028297
#
#        animal_type_Dog  animal_type_Other  intake_condition_Aged  \
# 76153         1.280638          -0.336747              -0.064802
# 47869        -0.780861           2.969592              -0.064802
# 33041         1.280638          -0.336747              -0.064802
# 23904        -0.780861          -0.336747              -0.064802
# 56601        -0.780861          -0.336747              -0.064802
# 19905        -0.780861          -0.336747              -0.064802
# 13789        -0.780861          -0.336747              -0.064802
# 53374        -0.780861          -0.336747              -0.064802
# 7560          1.280638          -0.336747              -0.064802
# 31902        -0.780861          -0.336747              -0.064802
# 48529        -0.780861          -0.336747              -0.064802
# 55942        -0.780861          -0.336747              -0.064802
# 65361        -0.780861          -0.336747              -0.064802
# 72934        -0.780861           2.969592              -0.064802
# 4722          1.280638          -0.336747              -0.064802
# 30075        -0.780861          -0.336747              -0.064802
# 57727        -0.780861          -0.336747              -0.064802
# 47032        -0.780861          -0.336747              -0.064802
# 60734         1.280638          -0.336747              -0.064802
# 50901        -0.780861          -0.336747              -0.064802
# 33940         1.280638          -0.336747              -0.064802
# 79533        -0.780861          -0.336747              -0.064802
# 15268        -0.780861          -0.336747              -0.064802
# 57222        -0.780861          -0.336747              -0.064802
# 56084         1.280638          -0.336747              -0.064802
# 23907        -0.780861          -0.336747              -0.064802
# 67638         1.280638          -0.336747              -0.064802
# 48110        -0.780861          -0.336747              -0.064802
# 71207        -0.780861          -0.336747              -0.064802
# 64009        -0.780861          -0.336747              -0.064802
# ...                ...                ...                    ...
# 49657         1.280638          -0.336747              -0.064802
# 45147        -0.780861          -0.336747              -0.064802
# 72207        -0.780861          -0.336747              -0.064802
# 33537        -0.780861          -0.336747              -0.064802
# 24133        -0.780861          -0.336747              -0.064802
# 66693         1.280638          -0.336747              -0.064802
# 38400         1.280638          -0.336747              -0.064802
# 13865        -0.780861          -0.336747              -0.064802
# 47408         1.280638          -0.336747              -0.064802
# 15001        -0.780861          -0.336747              -0.064802
# 54838        -0.780861          -0.336747              -0.064802
# 34836         1.280638          -0.336747              -0.064802
# 50723        -0.780861          -0.336747              -0.064802
# 15027         1.280638          -0.336747              -0.064802
# 39254        -0.780861          -0.336747              -0.064802
# 42800        -0.780861          -0.336747              -0.064802
# 64985        -0.780861           2.969592              -0.064802
# 27308        -0.780861          -0.336747              -0.064802
# 70328        -0.780861          -0.336747              -0.064802
# 73876        -0.780861          -0.336747              -0.064802
# 51568         1.280638          -0.336747              -0.064802
# 58388        -0.780861          -0.336747              -0.064802
# 42901        -0.780861           2.969592              -0.064802
# 28275        -0.780861           2.969592              -0.064802
# 13551        -0.780861          -0.336747              -0.064802
# 79106        -0.780861          -0.336747              -0.064802
# 24336        -0.780861          -0.336747              -0.064802
# 796           1.280638          -0.336747              -0.064802
# 1012          1.280638          -0.336747              -0.064802
# 34370         1.280638          -0.336747              -0.064802
#
#        intake_condition_Feral            ...             \
# 76153               -0.045774            ...
# 47869               -0.045774            ...
# 33041               -0.045774            ...
# 23904               -0.045774            ...
# 56601               -0.045774            ...
# 19905               -0.045774            ...
# 13789               -0.045774            ...
# 53374               -0.045774            ...
# 7560                -0.045774            ...
# 31902               -0.045774            ...
# 48529               -0.045774            ...
# 55942               -0.045774            ...
# 65361               -0.045774            ...
# 72934               -0.045774            ...
# 4722                -0.045774            ...
# 30075               -0.045774            ...
# 57727               -0.045774            ...
# 47032               -0.045774            ...
# 60734               -0.045774            ...
# 50901               -0.045774            ...
# 33940               -0.045774            ...
# 79533               -0.045774            ...
# 15268               -0.045774            ...
# 57222               -0.045774            ...
# 56084               -0.045774            ...
# 23907               -0.045774            ...
# 67638               -0.045774            ...
# 48110               -0.045774            ...
# 71207               -0.045774            ...
# 64009               -0.045774            ...
# ...                       ...            ...
# 49657               -0.045774            ...
# 45147               -0.045774            ...
# 72207               -0.045774            ...
# 33537               -0.045774            ...
# 24133               -0.045774            ...
# 66693               -0.045774            ...
# 38400               -0.045774            ...
# 13865               -0.045774            ...
# 47408               -0.045774            ...
# 15001               -0.045774            ...
# 54838               -0.045774            ...
# 34836               -0.045774            ...
# 50723               -0.045774            ...
# 15027               -0.045774            ...
# 39254               -0.045774            ...
# 42800               -0.045774            ...
# 64985               -0.045774            ...
# 27308               -0.045774            ...
# 70328               -0.045774            ...
# 73876               -0.045774            ...
# 51568               -0.045774            ...
# 58388               -0.045774            ...
# 42901               -0.045774            ...
# 28275               -0.045774            ...
# 13551               -0.045774            ...
# 79106               -0.045774            ...
# 24336               -0.045774            ...
# 796                 -0.045774            ...
# 1012                -0.045774            ...
# 34370               -0.045774            ...
#
#        sex_upon_intake_Intact Female  sex_upon_intake_Intact Male  \
# 76153                       1.444059                    -0.687193
# 47869                      -0.692492                    -0.687193
# 33041                      -0.692492                    -0.687193
# 23904                      -0.692492                    -0.687193
# 56601                       1.444059                    -0.687193
# 19905                      -0.692492                    -0.687193
# 13789                       1.444059                    -0.687193
# 53374                       1.444059                    -0.687193
# 7560                       -0.692492                    -0.687193
# 31902                      -0.692492                     1.455195
# 48529                      -0.692492                    -0.687193
# 55942                       1.444059                    -0.687193
# 65361                      -0.692492                    -0.687193
# 72934                      -0.692492                    -0.687193
# 4722                       -0.692492                    -0.687193
# 30075                      -0.692492                    -0.687193
# 57727                       1.444059                    -0.687193
# 47032                      -0.692492                     1.455195
# 60734                       1.444059                    -0.687193
# 50901                       1.444059                    -0.687193
# 33940                       1.444059                    -0.687193
# 79533                       1.444059                    -0.687193
# 15268                       1.444059                    -0.687193
# 57222                       1.444059                    -0.687193
# 56084                      -0.692492                     1.455195
# 23907                      -0.692492                    -0.687193
# 67638                      -0.692492                     1.455195
# 48110                      -0.692492                     1.455195
# 71207                      -0.692492                    -0.687193
# 64009                      -0.692492                     1.455195
# ...                              ...                          ...
# 49657                      -0.692492                    -0.687193
# 45147                      -0.692492                     1.455195
# 72207                       1.444059                    -0.687193
# 33537                      -0.692492                    -0.687193
# 24133                      -0.692492                    -0.687193
# 66693                       1.444059                    -0.687193
# 38400                       1.444059                    -0.687193
# 13865                       1.444059                    -0.687193
# 47408                       1.444059                    -0.687193
# 15001                       1.444059                    -0.687193
# 54838                       1.444059                    -0.687193
# 34836                      -0.692492                     1.455195
# 50723                      -0.692492                    -0.687193
# 15027                       1.444059                    -0.687193
# 39254                       1.444059                    -0.687193
# 42800                      -0.692492                    -0.687193
# 64985                      -0.692492                    -0.687193
# 27308                      -0.692492                    -0.687193
# 70328                       1.444059                    -0.687193
# 73876                       1.444059                    -0.687193
# 51568                       1.444059                    -0.687193
# 58388                      -0.692492                    -0.687193
# 42901                      -0.692492                    -0.687193
# 28275                      -0.692492                    -0.687193
# 13551                       1.444059                    -0.687193
# 79106                      -0.692492                     1.455195
# 24336                       1.444059                    -0.687193
# 796                        -0.692492                    -0.687193
# 1012                       -0.692492                    -0.687193
# 34370                       1.444059                    -0.687193
#
#        sex_upon_intake_Neutered Male  sex_upon_intake_Spayed Female  \
# 76153                      -0.334056                      -0.306318
# 47869                      -0.334056                      -0.306318
# 33041                      -0.334056                       3.264578
# 23904                      -0.334056                      -0.306318
# 56601                      -0.334056                      -0.306318
# 19905                      -0.334056                      -0.306318
# 13789                      -0.334056                      -0.306318
# 53374                      -0.334056                      -0.306318
# 7560                        2.993507                      -0.306318
# 31902                      -0.334056                      -0.306318
# 48529                      -0.334056                      -0.306318
# 55942                      -0.334056                      -0.306318
# 65361                      -0.334056                       3.264578
# 72934                      -0.334056                      -0.306318
# 4722                       -0.334056                       3.264578
# 30075                       2.993507                      -0.306318
# 57727                      -0.334056                      -0.306318
# 47032                      -0.334056                      -0.306318
# 60734                      -0.334056                      -0.306318
# 50901                      -0.334056                      -0.306318
# 33940                      -0.334056                      -0.306318
# 79533                      -0.334056                      -0.306318
# 15268                      -0.334056                      -0.306318
# 57222                      -0.334056                      -0.306318
# 56084                      -0.334056                      -0.306318
# 23907                      -0.334056                      -0.306318
# 67638                      -0.334056                      -0.306318
# 48110                      -0.334056                      -0.306318
# 71207                      -0.334056                      -0.306318
# 64009                      -0.334056                      -0.306318
# ...                              ...                            ...
# 49657                      -0.334056                       3.264578
# 45147                      -0.334056                      -0.306318
# 72207                      -0.334056                      -0.306318
# 33537                      -0.334056                       3.264578
# 24133                      -0.334056                       3.264578
# 66693                      -0.334056                      -0.306318
# 38400                      -0.334056                      -0.306318
# 13865                      -0.334056                      -0.306318
# 47408                      -0.334056                      -0.306318
# 15001                      -0.334056                      -0.306318
# 54838                      -0.334056                      -0.306318
# 34836                      -0.334056                      -0.306318
# 50723                      -0.334056                       3.264578
# 15027                      -0.334056                      -0.306318
# 39254                      -0.334056                      -0.306318
# 42800                       2.993507                      -0.306318
# 64985                      -0.334056                      -0.306318
# 27308                      -0.334056                       3.264578
# 70328                      -0.334056                      -0.306318
# 73876                      -0.334056                      -0.306318
# 51568                      -0.334056                      -0.306318
# 58388                      -0.334056                      -0.306318
# 42901                      -0.334056                      -0.306318
# 28275                      -0.334056                      -0.306318
# 13551                      -0.334056                      -0.306318
# 79106                      -0.334056                      -0.306318
# 24336                      -0.334056                      -0.306318
# 796                        -0.334056                       3.264578
# 1012                       -0.334056                       3.264578
# 34370                      -0.334056                      -0.306318
#
#        sex_upon_intake_Unknown  sex_upon_outcome_Intact Female  \
# 76153                -0.450885                        2.006835
# 47869                 2.217861                       -0.498297
# 33041                -0.450885                       -0.498297
# 23904                 2.217861                       -0.498297
# 56601                -0.450885                        2.006835
# 19905                 2.217861                       -0.498297
# 13789                -0.450885                        2.006835
# 53374                -0.450885                        2.006835
# 7560                 -0.450885                       -0.498297
# 31902                -0.450885                       -0.498297
# 48529                 2.217861                       -0.498297
# 55942                -0.450885                        2.006835
# 65361                -0.450885                       -0.498297
# 72934                 2.217861                       -0.498297
# 4722                 -0.450885                       -0.498297
# 30075                -0.450885                       -0.498297
# 57727                -0.450885                        2.006835
# 47032                -0.450885                       -0.498297
# 60734                -0.450885                        2.006835
# 50901                -0.450885                       -0.498297
# 33940                -0.450885                        2.006835
# 79533                -0.450885                        2.006835
# 15268                -0.450885                       -0.498297
# 57222                -0.450885                        2.006835
# 56084                -0.450885                       -0.498297
# 23907                 2.217861                       -0.498297
# 67638                -0.450885                       -0.498297
# 48110                -0.450885                       -0.498297
# 71207                 2.217861                       -0.498297
# 64009                -0.450885                       -0.498297
# ...                        ...                             ...
# 49657                -0.450885                       -0.498297
# 45147                -0.450885                       -0.498297
# 72207                -0.450885                        2.006835
# 33537                -0.450885                       -0.498297
# 24133                -0.450885                       -0.498297
# 66693                -0.450885                        2.006835
# 38400                -0.450885                        2.006835
# 13865                -0.450885                       -0.498297
# 47408                -0.450885                        2.006835
# 15001                -0.450885                       -0.498297
# 54838                -0.450885                       -0.498297
# 34836                -0.450885                       -0.498297
# 50723                -0.450885                       -0.498297
# 15027                -0.450885                       -0.498297
# 39254                -0.450885                        2.006835
# 42800                -0.450885                       -0.498297
# 64985                 2.217861                       -0.498297
# 27308                -0.450885                       -0.498297
# 70328                -0.450885                        2.006835
# 73876                -0.450885                        2.006835
# 51568                -0.450885                       -0.498297
# 58388                 2.217861                       -0.498297
# 42901                 2.217861                       -0.498297
# 28275                 2.217861                       -0.498297
# 13551                -0.450885                        2.006835
# 79106                -0.450885                       -0.498297
# 24336                -0.450885                        2.006835
# 796                  -0.450885                       -0.498297
# 1012                 -0.450885                       -0.498297
# 34370                -0.450885                        2.006835
#
#        sex_upon_outcome_Intact Male  sex_upon_outcome_Neutered Male  \
# 76153                     -0.486610                       -0.546067
# 47869                     -0.486610                       -0.546067
# 33041                     -0.486610                       -0.546067
# 23904                     -0.486610                       -0.546067
# 56601                     -0.486610                       -0.546067
# 19905                     -0.486610                       -0.546067
# 13789                     -0.486610                       -0.546067
# 53374                     -0.486610                       -0.546067
# 7560                      -0.486610                        1.831277
# 31902                     -0.486610                        1.831277
# 48529                     -0.486610                       -0.546067
# 55942                     -0.486610                       -0.546067
# 65361                     -0.486610                       -0.546067
# 72934                     -0.486610                       -0.546067
# 4722                      -0.486610                       -0.546067
# 30075                     -0.486610                        1.831277
# 57727                     -0.486610                       -0.546067
# 47032                     -0.486610                        1.831277
# 60734                     -0.486610                       -0.546067
# 50901                     -0.486610                       -0.546067
# 33940                     -0.486610                       -0.546067
# 79533                     -0.486610                       -0.546067
# 15268                     -0.486610                       -0.546067
# 57222                     -0.486610                       -0.546067
# 56084                      2.055034                       -0.546067
# 23907                     -0.486610                       -0.546067
# 67638                      2.055034                       -0.546067
# 48110                     -0.486610                        1.831277
# 71207                     -0.486610                       -0.546067
# 64009                      2.055034                       -0.546067
# ...                             ...                             ...
# 49657                     -0.486610                       -0.546067
# 45147                     -0.486610                        1.831277
# 72207                     -0.486610                       -0.546067
# 33537                     -0.486610                       -0.546067
# 24133                     -0.486610                       -0.546067
# 66693                     -0.486610                       -0.546067
# 38400                     -0.486610                       -0.546067
# 13865                     -0.486610                       -0.546067
# 47408                     -0.486610                       -0.546067
# 15001                     -0.486610                       -0.546067
# 54838                     -0.486610                       -0.546067
# 34836                      2.055034                       -0.546067
# 50723                     -0.486610                       -0.546067
# 15027                     -0.486610                       -0.546067
# 39254                     -0.486610                       -0.546067
# 42800                     -0.486610                        1.831277
# 64985                     -0.486610                       -0.546067
# 27308                     -0.486610                       -0.546067
# 70328                     -0.486610                       -0.546067
# 73876                     -0.486610                       -0.546067
# 51568                     -0.486610                       -0.546067
# 58388                     -0.486610                       -0.546067
# 42901                     -0.486610                       -0.546067
# 28275                     -0.486610                       -0.546067
# 13551                     -0.486610                       -0.546067
# 79106                      2.055034                       -0.546067
# 24336                     -0.486610                       -0.546067
# 796                       -0.486610                       -0.546067
# 1012                      -0.486610                       -0.546067
# 34370                     -0.486610                       -0.546067
#
#        sex_upon_outcome_Spayed Female  sex_upon_outcome_Unknown
# 76153                       -0.517115                 -0.450885
# 47869                       -0.517115                  2.217861
# 33041                        1.933805                 -0.450885
# 23904                       -0.517115                  2.217861
# 56601                       -0.517115                 -0.450885
# 19905                       -0.517115                  2.217861
# 13789                       -0.517115                 -0.450885
# 53374                       -0.517115                 -0.450885
# 7560                        -0.517115                 -0.450885
# 31902                       -0.517115                 -0.450885
# 48529                       -0.517115                  2.217861
# 55942                       -0.517115                 -0.450885
# 65361                        1.933805                 -0.450885
# 72934                       -0.517115                  2.217861
# 4722                         1.933805                 -0.450885
# 30075                       -0.517115                 -0.450885
# 57727                       -0.517115                 -0.450885
# 47032                       -0.517115                 -0.450885
# 60734                       -0.517115                 -0.450885
# 50901                        1.933805                 -0.450885
# 33940                       -0.517115                 -0.450885
# 79533                       -0.517115                 -0.450885
# 15268                        1.933805                 -0.450885
# 57222                       -0.517115                 -0.450885
# 56084                       -0.517115                 -0.450885
# 23907                       -0.517115                  2.217861
# 67638                       -0.517115                 -0.450885
# 48110                       -0.517115                 -0.450885
# 71207                       -0.517115                  2.217861
# 64009                       -0.517115                 -0.450885
# ...                               ...                       ...
# 49657                        1.933805                 -0.450885
# 45147                       -0.517115                 -0.450885
# 72207                       -0.517115                 -0.450885
# 33537                        1.933805                 -0.450885
# 24133                        1.933805                 -0.450885
# 66693                       -0.517115                 -0.450885
# 38400                       -0.517115                 -0.450885
# 13865                        1.933805                 -0.450885
# 47408                       -0.517115                 -0.450885
# 15001                        1.933805                 -0.450885
# 54838                        1.933805                 -0.450885
# 34836                       -0.517115                 -0.450885
# 50723                        1.933805                 -0.450885
# 15027                        1.933805                 -0.450885
# 39254                       -0.517115                 -0.450885
# 42800                       -0.517115                 -0.450885
# 64985                       -0.517115                  2.217861
# 27308                        1.933805                 -0.450885
# 70328                       -0.517115                 -0.450885
# 73876                       -0.517115                 -0.450885
# 51568                        1.933805                 -0.450885
# 58388                       -0.517115                  2.217861
# 42901                       -0.517115                  2.217861
# 28275                       -0.517115                  2.217861
# 13551                       -0.517115                 -0.450885
# 79106                       -0.517115                 -0.450885
# 24336                       -0.517115                 -0.450885
# 796                          1.933805                 -0.450885
# 1012                         1.933805                 -0.450885
# 34370                       -0.517115                 -0.450885
#
# [7270 rows x 31 columns]

# %%
# testing greedy backward selection without 
names = x_train.columns
acc_list = []
for i in range(len(names)):
    x_tr_drop = x_train.drop(columns = names [i])
    x_te_drop = x_test.drop(columns = names [i])
    y_pred_prob = logistic.fit(x_tr_drop, y_train).predict_proba(x_test)
    y_pred_tmp =(y_pred_prob[:,1] >= 0.5).astype(int)
    acc = np.mean(abs(y_test-y_pred_tmp))
    acc_list.append(acc)

# %%
np.mean(abs(y_test-y_pred_tmp))
# Out:
# 0.06781292984869326
